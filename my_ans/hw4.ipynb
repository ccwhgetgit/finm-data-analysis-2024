# %%
import pandas as pd 
from sklearn.decomposition import PCA 
returns = pd.read_excel('./../data/spx_weekly_returns_single_names.xlsx', sheet_name = 2)
spy = pd.read_excel('./../data/spx_weekly_returns_single_names.xlsx', sheet_name = 3)['SPY']
returns = returns.set_index('date')
pca = PCA()
pca.fit(returns.values)
pca_transformed_data = pca.transform(returns.values)
components = pca.n_components_
df = pd.DataFrame(pca_transformed_data)
df.columns = ['PC' + str(i) for i in range(1, components + 1)]
df.index = returns.index
df.head()
# Out:
#                  PC1       PC2       PC3       PC4       PC5       PC6  \
# date
# 2016-01-15  0.703385 -0.077855 -0.239065 -0.172304  0.140798  0.211526
# 2016-01-22 -0.227620 -0.064802 -0.005063  0.178815 -0.182955  0.054410
# 2016-01-29 -0.343365  0.066115 -0.080619  0.204560  0.001394  0.133521
# 2016-02-05  0.639496  0.166702 -0.215107 -0.061996  0.165133 -0.033232
# 2016-02-12  0.431774 -0.114435 -0.002420 -0.046339  0.239280  0.073124
#
#                  PC7       PC8       PC9      PC10  ...     PC430  \
# date                                                ...
# 2016-01-15 -0.001276  0.027892 -0.096028  0.009757  ... -0.000088
# 2016-01-22  0.034111 -0.027683 -0.041873 -0.013611  ... -0.001040
# 2016-01-29  0.269311  0.055258 -0.184666  0.083771  ... -0.000646
# 2016-02-05  0.429579  0.002246 -0.057776 -0.033772  ... -0.000527
# 2016-02-12 -0.191123  0.147314 -0.183536  0.170020  ... -0.000698
#
# ...

# %%
explained_var = pd.DataFrame(data = pca.explained_variance_ratio_,
                                 index = pca_factors.columns, 
                                 columns = ['Explained Variance'])
explained_var['Cumulative Explained Variance'] = explained_var['Explained Variance'].cumsum()
explained_var
# Out:
#         Explained Variance  Cumulative Explained Variance
# PC 1          3.891038e-01                       0.389104
# PC 2          5.674446e-02                       0.445848
# PC 3          3.778359e-02                       0.483632
# PC 4          2.774486e-02                       0.511377
# PC 5          2.073423e-02                       0.532111
# ...                    ...                            ...
# PC 435        2.122274e-07                       1.000000
# PC 436        1.800606e-07                       1.000000
# PC 437        1.101054e-07                       1.000000
# PC 438        1.008458e-07                       1.000000
# PC 439        2.080413e-33                       1.000000
#
# [439 rows x 2 columns]
